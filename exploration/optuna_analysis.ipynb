# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import joblib
from optuna.visualization import plot_contour
from optuna.visualization import plot_edf
from optuna.visualization import plot_intermediate_values
from optuna.visualization import plot_optimization_history
from optuna.visualization import plot_parallel_coordinate
from optuna.visualization import plot_param_importances
from optuna.visualization import plot_rank
from optuna.visualization import plot_slice
from optuna.visualization import plot_timeline

# %%
datasets=["femto_booking_agilkia_v6","spree_5000_session_wo_responses_agilkia","teaming_execution","scanette_100043-steps"]
studies=[]
for dataset_name in datasets:
    name_study="../data/studies/study_"+dataset_name+"_transformers.pkl"
    studies.append(joblib.load(name_study))

# %%
def plot_optuna(studies,datasets,function):
    for study,dataset_name in zip(studies,datasets):
        print(dataset_name)
        fig=function(study)
        fig.show()

# %%
plot_optuna(studies,datasets,plot_rank)
# Out:
# femto_booking_agilkia_v6
# /tmp/ipykernel_3155/356455782.py:4: ExperimentalWarning:
#
# plot_rank is experimental (supported from v3.2.0). The interface can change in the future.
# ...

# %%
plot_optuna(studies,datasets,plot_optimization_history)
# Out:
# femto_booking_agilkia_v6
# ...
